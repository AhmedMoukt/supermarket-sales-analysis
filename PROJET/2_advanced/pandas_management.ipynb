# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt 
dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df.head()
# Out:
#         job_title_short  ...                                    job_type_skills
# 0  Senior Data Engineer  ...                                               None
# 1          Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2         Data Engineer  ...  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3         Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4         Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
#
# [5 rows x 17 columns]

# %%
df.sample(10,)
# Out:
#             job_title_short  \
# 634301         Data Analyst
# 401967       Data Scientist
# 757070  Senior Data Analyst
# 119795       Data Scientist
# 754070    Software Engineer
# 54038          Data Analyst
# 480250         Data Analyst
# 108683        Data Engineer
# 741252        Data Engineer
# 158469         Data Analyst
#
#                                                 job_title  \
# 634301  Financial Data Analyst | Hybrid | Midshift | S...
# 401967            Data Scientist - Computer Vision Expert
# 757070           Senior Data Analytics Consultant (m/w/d)
# 119795                           Principal Data Scientist
# 754070                                  Software Engineer
# 54038                 Pm Data Analytics con Idioma Ingles
# 480250                             Financial Data Analyst
# 108683                        Lead Data Engineer (PANAMA)
# 741252                                      Data Engineer
# 158469                  Market research analytics Manager
#
# ...

# %%
dataset=load_dataset('lukebarousse/data_jobs')
df_original=dataset['train'].to_pandas()

# %%
df_altered=df_original

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
median_salary=df_altered['salary_year_avg'].median()
median_salary
# Out:
# 115000.0

# %%
df_altered['salary_year_avg']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 785736   NaN
# 785737   NaN
# 785738   NaN
# 785739   NaN
# 785740   NaN
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
df_altered['salary_year_avg']=df_altered['salary_year_avg'].fillna(median_salary)
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_altered
# Out:
#              job_title_short  ...                                    job_type_skills
# 0       Senior Data Engineer  ...                                               None
# 1               Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2              Data Engineer  ...  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3              Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4              Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                      ...  ...                                                ...
# 785736     Software Engineer  ...  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737          Data Analyst  ...  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738      Business Analyst  ...         {'analyst_tools': ['powerpoint', 'excel']}
# 785739         Data Engineer  ...  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# ...

# %%
id(df_original)
# Out:
# 1930479143200

# %%
id(df_altered)
# Out:
# 1928650324208

# %%
df_altered=df_original.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
median_salary=df_altered['salary_year_avg'].median()
df_altered['salary_year_avg']=df_altered['salary_year_avg'].fillna(median_salary)
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original['salary_year_avg']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 785736   NaN
# 785737   NaN
# 785738   NaN
# 785739   NaN
# 785740   NaN
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
id(df_altered)
# Out:
# 1930479151840

# %%
median_salary
# Out:
# 115000.0

# %%
df.index.name='job_index'

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df=df.reset_index(drop=True)

# %%
df_usa=df[df['job_country']=='United States']

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_usa.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_usa.reset_index(inplace=True)
#
# NameError: name 'df_usa' is not defined

# %%
df.set_index('job_index',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15900\117436868.py in ?()
# ----> 1 df.set_index('job_index',inplace=True)
#
# c:\Users\ahmed\anaconda3\envs\python_course\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['job_index'] are in the columns"

# %%
df.index.name='job_index'

# %%
df
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
# ...                         ...
# 785736        Software Engineer
# 785737             Data Analyst
# 785738         Business Analyst
# 785739            Data Engineer
# 785740        Software Engineer
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
# ...                                                      ...
# 785736                                       DevOps Engineer
# ...

# %%
median_pivot=df_usa.pivot_table(values='salary_year_avg',index='job_title_short',aggfunc=['median','min','max'])
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  90000.0         35000.0        387460.0
# Cloud Engineer                   116100.0         42000.0        221844.0
# Data Analyst                      90000.0         25000.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Senior Data Scientist            155000.0         55000.0        475000.0
# Software Engineer                130000.0         48982.0        375000.0

# %%
median_pivot.sort_values(by=('job_title_short'),ascending=True)
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  90000.0         35000.0        387460.0
# Cloud Engineer                   116100.0         42000.0        221844.0
# Data Analyst                      90000.0         25000.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Senior Data Scientist            155000.0         55000.0        475000.0
# Software Engineer                130000.0         48982.0        375000.0

# %%
median_pivot.sort_index(inplace=    True)

# %%
top_jobc=df.pivot_table(values='salary_year_avg',index='job_country',columns='job_title_short',aggfunc='median')
median_salary1=top_jobc.median()
top_jobc.sort_values(by=(median_salary1))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15900\1425575363.py in ?()
#       1 top_jobc=df.pivot_table(values='salary_year_avg',index='job_country',columns='job_title_short',aggfunc='median')
#       2 median_salary1=top_jobc.median()
# ----> 3 top_jobc.sort_values(by=(median_salary1))
#
# c:\Users\ahmed\anaconda3\envs\python_course\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7185             )
#    7186         elif len(by):
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#    7192             if key is not None:
#
# ...
