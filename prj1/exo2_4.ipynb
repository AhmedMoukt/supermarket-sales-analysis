# %%
import pandas as pd
df=pd.read_csv("supermarket_sales - Sheet1.csv")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df[df["country"].notnull()]
# Out:
#      show_id     type                          title         director  \
# 0         s1    Movie           Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show                  Blood & Water              NaN
# 4         s5  TV Show                   Kota Factory              NaN
# 7         s8    Movie                        Sankofa     Haile Gerima
# 8         s9  TV Show  The Great British Baking Show  Andy Devonshire
# ...      ...      ...                            ...              ...
# 8801   s8802    Movie                        Zinzana  Majid Al Ansari
# 8802   s8803    Movie                         Zodiac    David Fincher
# 8804   s8805    Movie                     Zombieland  Ruben Fleischer
# 8805   s8806    Movie                           Zoom     Peter Hewitt
# 8806   s8807    Movie                         Zubaan      Mozez Singh
#
#                                                    cast  \
# 0                                                   NaN
# ...

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df["tva 3%"]=df["Unit price"]*(3/100)

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
Citys={"Yangon":"YG","Naypyitaw":"NT","Mandalay":"ML"}
df['City_code']=df["City"].map(Citys)

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
df["City"].describe()
# Out:
# count       1000
# unique         3
# top       Yangon
# freq         340
# Name: City, dtype: object

# %%
df["Total"].mean()
# Out:
# np.float64(322.966749)

# %%
df["Unit price"].sum()
# Out:
# np.float64(55672.130000000005)

# %%
df["Unit price"].min()
# Out:
# np.float64(10.08)

# %%
df["Unit price"].max()
# Out:
# np.float64(99.96)

# %%
df["City"].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df["City"].value_counts()
# Out:
# City
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: count, dtype: int64

# %%
df["Customer type"].value_counts()
# Out:
# Customer type
# Member    501
# Normal    499
# Name: count, dtype: int64

# %%
df["Customer type"].min()
# Out:
# 'Member'

# %%
df["Customer type"].max()
# Out:
# 'Normal'

# %%
df["Customer type"].value_counts(normalize=True)
# Out:
# Customer type
# Member    0.501
# Normal    0.499
# Name: proportion, dtype: float64

# %%
df.groupby("City").sum()
# Out:
#                                                   Invoice ID  \
# City
# Mandalay   692-92-5582351-62-0822529-56-3974299-46-180531...
# Naypyitaw  226-31-3081699-14-3026315-22-5665300-71-460518...
# Yangon     750-67-8428631-41-3108123-19-1176373-73-791035...
#
#                                                       Branch  \
# City
# Mandalay   BBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBB...
# Naypyitaw  CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# Yangon     AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA...
#
#                                                Customer type  \
# City
# Mandalay   MemberMemberMemberMemberNormalNormalNormalNorm...
# Naypyitaw  NormalNormalNormalMemberMemberMemberNormalMemb...
# Yangon     MemberNormalMemberNormalMemberMemberNormalNorm...
#
#                                                       Gender  \
# City
# Mandalay   FemaleFemaleMaleFemaleFemaleMaleMaleMaleFemale...
# Naypyitaw  FemaleMaleFemaleMaleFemaleFemaleFemaleMaleFema...
# ...

# %%
df.groupby("Customer type")["Total"].sum()
# Out:
# Customer type
# Member    164223.444
# Normal    158743.305
# Name: Total, dtype: float64

# %%
df.groupby(["Customer type","City"]).sum()
# Out:
#                                                                 Invoice ID  \
# Customer type City
# Member        Mandalay   692-92-5582351-62-0822529-56-3974299-46-180514...
#               Naypyitaw  300-71-4605183-56-6882232-16-2483554-53-870022...
#               Yangon     750-67-8428123-19-1176355-53-5943665-32-916765...
# Normal        Mandalay   319-50-3348371-85-5789273-16-6619649-29-677514...
#               Naypyitaw  226-31-3081699-14-3026315-22-5665333-73-790139...
#               Yangon     631-41-3108373-73-7910365-64-0515252-56-269982...
#
#                                                                     Branch  \
# Customer type City
# Member        Mandalay   BBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBB...
#               Naypyitaw  CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
#               Yangon     AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA...
# Normal        Mandalay   BBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBBB...
# ...

# %%
df.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  3/3/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4

# %%
df.groupby("Date")["Total"].sum().plot(figsize=[15,10])
# Out:
# <Axes: xlabel='Date'>

# %%
df.groupby("City")["Total"].sum().plot()
# Out:
# <Axes: xlabel='City'>

# %%
df.groupby("City")["Total"].max().plot()
# Out:
# <Axes: xlabel='City'>

# %%
df.groupby("City")["Total"].sum().plot.pie(legend=True)
# Out:
# <Axes: ylabel='Total'>

# %%
df.groupby("City")["Total"].sum().plot.bar(rot=45,legend=True)
# Out:
# <Axes: xlabel='City'>
