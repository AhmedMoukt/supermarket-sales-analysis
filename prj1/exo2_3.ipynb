# %%
import pandas as pd
df=pd.read_csv("netflix_titles.csv")

# %%
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df.tail()
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667

# %%
df.tail()
df.head()
df.head(3)
df.set_index
# Out:
# <bound method DataFrame.set_index of       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
# ...

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df[df["country"]=="India"]
# Out:
#      show_id     type                          title                 director  \
# 4         s5  TV Show                   Kota Factory                      NaN
# 24       s25    Movie                          Jeans               S. Shankar
# 39       s40  TV Show                   Chhota Bheem                      NaN
# 50       s51  TV Show                  Dharmakshetra                      NaN
# 66       s67  TV Show  Raja Rasoi Aur Anya Kahaniyan                      NaN
# ...      ...      ...                            ...                      ...
# 8773   s8774    Movie            Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show                Yeh Meri Family                      NaN
# 8798   s8799    Movie                       Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                          Zenda           Avadhoot Gupte
# 8806   s8807    Movie                         Zubaan              Mozez Singh
#
# ...

# %%
df[df["country"].isin(["India","South Africa"])]
# Out:
#      show_id     type                title                 director  \
# 1         s2  TV Show        Blood & Water                      NaN
# 4         s5  TV Show         Kota Factory                      NaN
# 24       s25    Movie                Jeans               S. Shankar
# 39       s40  TV Show         Chhota Bheem                      NaN
# 50       s51  TV Show        Dharmakshetra                      NaN
# ...      ...      ...                  ...                      ...
# 8773   s8774    Movie  Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show      Yeh Meri Family                      NaN
# 8798   s8799    Movie             Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                Zenda           Avadhoot Gupte
# 8806   s8807    Movie               Zubaan              Mozez Singh
#
#                                                    cast       country  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# ...

# %%
df.title.head()
# Out:
# 0     Dick Johnson Is Dead
# 1            Blood & Water
# 2                Ganglands
# 3    Jailbirds New Orleans
# 4             Kota Factory
# Name: title, dtype: object

# %%
df_title=df.set_index("title")
df_title.loc["Midnight Mass"].values.tolist()
# Out:
# ['s6',
#  'TV Show',
#  'Mike Flanagan',
#  'Kate Siegel, Zach Gilford, Hamish Linklater, Henry Thomas, Kristin Lehman, Samantha Sloyan, Igby Rigney, Rahul Kohli, Annarah Cymone, Annabeth Gish, Alex Essoe, Rahul Abburi, Matt Biedel, Michael Trucco, Crystal Balint, Louis Oliver',
#  nan,
#  'September 24, 2021',
#  np.int64(2021),
#  'TV-MA',
#  '1 Season',
#  'TV Dramas, TV Horror, TV Mysteries',
#  'The arrival of a charismatic young priest brings glorious miracles, ominous mysteries and renewed religious fervor to a dying town desperate to believe.']

# %%
df[df["country"].isin(["India"])].head(3)
# Out:
#    show_id     type         title    director  \
# 4       s5  TV Show  Kota Factory         NaN
# 24     s25    Movie         Jeans  S. Shankar
# 39     s40  TV Show  Chhota Bheem         NaN
#
#                                                  cast country  \
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
# 39  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...   India
#
#             date_added  release_year rating   duration  \
# 4   September 24, 2021          2021  TV-MA  2 Seasons
# 24  September 21, 2021          1998  TV-14    166 min
# 39  September 16, 2021          2021  TV-Y7  3 Seasons
#
#                                             listed_in  \
# 4   International TV Shows, Romantic TV Shows, TV ...
# 24    Comedies, International Movies, Romantic Movies
# 39                                           Kids' TV
#
#                                           description
# ...

# %%
df_test=df.copy()
df_test.show_id=df_test.show_id.apply(lambda x: x.replace("s",""))
df_test.show_id=df_test.show_id.astype(int)
df_test[df_test["show_id"]>=5]
# Out:
#       show_id     type                             title  \
# 4           5  TV Show                      Kota Factory
# 5           6  TV Show                     Midnight Mass
# 6           7    Movie  My Little Pony: A New Generation
# 7           8    Movie                           Sankofa
# 8           9  TV Show     The Great British Baking Show
# ...       ...      ...                               ...
# 8802     8803    Movie                            Zodiac
# 8803     8804  TV Show                       Zombie Dumb
# 8804     8805    Movie                        Zombieland
# 8805     8806    Movie                              Zoom
# 8806     8807    Movie                            Zubaan
#
#                            director  \
# 4                               NaN
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 8                   Andy Devonshire
# ...                             ...
# ...

# %%
df[df["show_id"]>="s6"]
# Out:
#      show_id     type                             title  \
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# 8         s9  TV Show     The Great British Baking Show
# 59       s60    Movie       Naruto Shippuden: The Movie
# ...      ...      ...                               ...
# 8802   s8803    Movie                            Zodiac
# 8803   s8804  TV Show                       Zombie Dumb
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 8                   Andy Devonshire
# 59                  Hajime Kamegaki
# ...                             ...
# ...

# %%
df.set_index("country",inplace=True)

# %%
df
# Out:
#               show_id     type                  title         director  \
# country
# United States      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# South Africa       s2  TV Show          Blood & Water              NaN
# NaN                s3  TV Show              Ganglands  Julien Leclercq
# NaN                s4  TV Show  Jailbirds New Orleans              NaN
# India              s5  TV Show           Kota Factory              NaN
# ...               ...      ...                    ...              ...
# United States   s8803    Movie                 Zodiac    David Fincher
# NaN             s8804  TV Show            Zombie Dumb              NaN
# United States   s8805    Movie             Zombieland  Ruben Fleischer
# United States   s8806    Movie                   Zoom     Peter Hewitt
# India           s8807    Movie                 Zubaan      Mozez Singh
#
#                                                             cast  \
# country
# ...

# %%
df.drop("South Africa",axis=0,inplace=True)

# %%
df
# Out:
#               show_id     type                  title         director  \
# country
# United States      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# NaN                s3  TV Show              Ganglands  Julien Leclercq
# NaN                s4  TV Show  Jailbirds New Orleans              NaN
# India              s5  TV Show           Kota Factory              NaN
# NaN                s6  TV Show          Midnight Mass    Mike Flanagan
# ...               ...      ...                    ...              ...
# United States   s8803    Movie                 Zodiac    David Fincher
# NaN             s8804  TV Show            Zombie Dumb              NaN
# United States   s8805    Movie             Zombieland  Ruben Fleischer
# United States   s8806    Movie                   Zoom     Peter Hewitt
# India           s8807    Movie                 Zubaan      Mozez Singh
#
#                                                             cast  \
# country
# ...

# %%
df
# Out:
#               show_id     type                  title         director  \
# country
# United States      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# NaN                s3  TV Show              Ganglands  Julien Leclercq
# NaN                s4  TV Show  Jailbirds New Orleans              NaN
# India              s5  TV Show           Kota Factory              NaN
# NaN                s6  TV Show          Midnight Mass    Mike Flanagan
# ...               ...      ...                    ...              ...
# United States   s8803    Movie                 Zodiac    David Fincher
# NaN             s8804  TV Show            Zombie Dumb              NaN
# United States   s8805    Movie             Zombieland  Ruben Fleischer
# United States   s8806    Movie                   Zoom     Peter Hewitt
# India           s8807    Movie                 Zubaan      Mozez Singh
#
#                                                             cast  \
# country
# ...

# %%
df.drop("description",axis=1,inplace=True)

# %%
df
# Out:
#               show_id     type                  title         director  \
# country
# United States      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# NaN                s3  TV Show              Ganglands  Julien Leclercq
# NaN                s4  TV Show  Jailbirds New Orleans              NaN
# India              s5  TV Show           Kota Factory              NaN
# NaN                s6  TV Show          Midnight Mass    Mike Flanagan
# ...               ...      ...                    ...              ...
# United States   s8803    Movie                 Zodiac    David Fincher
# NaN             s8804  TV Show            Zombie Dumb              NaN
# United States   s8805    Movie             Zombieland  Ruben Fleischer
# United States   s8806    Movie                   Zoom     Peter Hewitt
# India           s8807    Movie                 Zubaan      Mozez Singh
#
#                                                             cast  \
# country
# ...

# %%
df.set_index("type",inplace=True)

# %%
df
# Out:
#         show_id                  title         director  \
# type
# Movie        s1   Dick Johnson Is Dead  Kirsten Johnson
# TV Show      s3              Ganglands  Julien Leclercq
# TV Show      s4  Jailbirds New Orleans              NaN
# TV Show      s5           Kota Factory              NaN
# TV Show      s6          Midnight Mass    Mike Flanagan
# ...         ...                    ...              ...
# Movie     s8803                 Zodiac    David Fincher
# TV Show   s8804            Zombie Dumb              NaN
# Movie     s8805             Zombieland  Ruben Fleischer
# Movie     s8806                   Zoom     Peter Hewitt
# Movie     s8807                 Zubaan      Mozez Singh
#
#                                                       cast  \
# type
# Movie                                                  NaN
# TV Show  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# TV Show                                                NaN
# ...

# %%
df.drop("TV Show",axis=0,inplace=True)

# %%
df
# Out:
#       show_id                             title  \
# type
# Movie      s1              Dick Johnson Is Dead
# Movie      s7  My Little Pony: A New Generation
# Movie      s8                           Sankofa
# Movie     s10                      The Starling
# Movie     s13                      Je Suis Karl
# ...       ...                               ...
# Movie   s8802                           Zinzana
# Movie   s8803                            Zodiac
# Movie   s8805                        Zombieland
# Movie   s8806                              Zoom
# Movie   s8807                            Zubaan
#
#                             director  \
# type
# Movie                Kirsten Johnson
# Movie  Robert Cullen, José Luis Ucha
# Movie                   Haile Gerima
# Movie                 Theodore Melfi
# Movie            Christian Schwochow
# ...                              ...
# Movie                Majid Al Ansari
# Movie                  David Fincher
# ...

# %%
df[df["cast"]=="Maisie Benson, Paul Killam, Kerry Gudjohnsen, AC Lim"]
# Out:
#       show_id                                         title  \
# type
# Movie     s24  Go! Go! Cory Carson: Chrissy Takes the Wheel
#
#                       director  \
# type
# Movie  Alex Woo, Stanley Moore
#
#                                                     cast          date_added  \
# type
# Movie  Maisie Benson, Paul Killam, Kerry Gudjohnsen, ...  September 21, 2021
#
#        release_year rating duration                 listed_in
# type
# Movie          2021   TV-Y   61 min  Children & Family Movies

# %%
df_test=df.copy()
df_test.show_id=df_test.show_id.apply(lambda x: x.replace("s",""))
df_test.show_id=df_test.show_id.astype(int)
df_test[df_test["show_id"]>=5]
# Out:
#       show_id     type                                title  \
# 9          10    Movie                         The Starling
# 10         11  TV Show  Vendetta: Truth, Lies and The Mafia
# 11         12  TV Show                     Bangkok Breaking
# 12         13    Movie                         Je Suis Karl
# 13         14    Movie     Confessions of an Invisible Girl
# ...       ...      ...                                  ...
# 8802     8803    Movie                               Zodiac
# 8803     8804  TV Show                          Zombie Dumb
# 8804     8805    Movie                           Zombieland
# 8805     8806    Movie                                 Zoom
# 8806     8807    Movie                               Zubaan
#
#                  director                                               cast  \
# 9          Theodore Melfi  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 10                    NaN                                                NaN
# ...

# %%
df[df[]]

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.set_index("type",inplace=True)

# %%
df.drop("Movie",axis=0,inplace=True)

# %%
df
# Out:
#         show_id                  title         director  \
# type
# TV Show      s2          Blood & Water              NaN
# TV Show      s3              Ganglands  Julien Leclercq
# TV Show      s4  Jailbirds New Orleans              NaN
# TV Show      s5           Kota Factory              NaN
# TV Show      s6          Midnight Mass    Mike Flanagan
# ...         ...                    ...              ...
# TV Show   s8796        Yu-Gi-Oh! Arc-V              NaN
# TV Show   s8797             Yunus Emre              NaN
# TV Show   s8798              Zak Storm              NaN
# TV Show   s8801     Zindagi Gulzar Hai              NaN
# TV Show   s8804            Zombie Dumb              NaN
#
#                                                       cast  \
# type
# TV Show  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# TV Show  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# TV Show                                                NaN
# ...

# %%
df.isnull()
# Out:
#          show_id  title  director   cast  country  date_added  release_year  \
# type
# TV Show    False  False      True  False    False       False         False
# TV Show    False  False     False  False     True       False         False
# TV Show    False  False      True   True     True       False         False
# TV Show    False  False      True  False    False       False         False
# TV Show    False  False     False  False     True       False         False
# ...          ...    ...       ...    ...      ...         ...           ...
# TV Show    False  False      True  False    False       False         False
# TV Show    False  False      True  False    False       False         False
# TV Show    False  False      True  False    False       False         False
# TV Show    False  False      True  False    False       False         False
# TV Show    False  False      True   True     True       False         False
#
#          rating  duration  listed_in  description
# ...

# %%
df[df["director"].notnull()]
# Out:
#         show_id                                              title  \
# type
# TV Show      s3                                          Ganglands
# TV Show      s6                                      Midnight Mass
# TV Show      s9                      The Great British Baking Show
# TV Show     s12                                   Bangkok Breaking
# TV Show     s21    Monsters Inside: The 24 Faces of Billy Milligan
# ...         ...                                                ...
# TV Show   s8236                                        The Calling
# TV Show   s8294                                           The Fear
# TV Show   s8303                                           The Five
# TV Show   s8550  The Vietnam War: A Film by Ken Burns and Lynn ...
# TV Show   s8600                                    Toast of London
#
#                        director  \
# type
# TV Show         Julien Leclercq
# TV Show           Mike Flanagan
# TV Show         Andy Devonshire
# ...

# %%
df["director"].fillna(0)
# Out:
# type
# TV Show                  0
# TV Show    Julien Leclercq
# TV Show                  0
# TV Show                  0
# TV Show      Mike Flanagan
#                 ...
# TV Show                  0
# TV Show                  0
# TV Show                  0
# TV Show                  0
# TV Show                  0
# Name: director, Length: 2676, dtype: object

# %%
df.dropna(subset=["director"],inplace=True)

# %%
df
# Out:
#         show_id                                              title  \
# type
# TV Show      s3                                          Ganglands
# TV Show      s6                                      Midnight Mass
# TV Show      s9                      The Great British Baking Show
# TV Show     s12                                   Bangkok Breaking
# TV Show     s21    Monsters Inside: The 24 Faces of Billy Milligan
# ...         ...                                                ...
# TV Show   s8236                                        The Calling
# TV Show   s8294                                           The Fear
# TV Show   s8303                                           The Five
# TV Show   s8550  The Vietnam War: A Film by Ken Burns and Lynn ...
# TV Show   s8600                                    Toast of London
#
#                        director  \
# type
# TV Show         Julien Leclercq
# TV Show           Mike Flanagan
# TV Show         Andy Devonshire
# ...
